# %%
import win32com.client
import time
import winsound
speaker = win32com.client.Dispatch("SAPI.SpVoice")

# %%
#for i in range(4):
    #winsound.Beep(600,1000)
    #time.sleep(0.1)
#winsound.Beep(1000,1000)
time.sleep(0.2)
speaker.Speak("天黑请闭眼。")
time.sleep(1)
speaker.Speak("狼人请睁眼，请互相确认同伴。")
time.sleep(0.1)
for i in range(5):
    speaker.Speak(str(5-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("白狼王请睁眼，请将墓地里的狼人牌与场上一名玩家进行互换。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("恶魔请睁眼，请查看任意一名玩家身份。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("替罪羊请睁眼，请全体狼人竖起大拇指，替罪羊请确认狼人身份。")
time.sleep(0.1)
for i in range(5):
    speaker.Speak(str(5-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("强盗请睁眼，请查看其他一名玩家身份，并与自己交换。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("女巫请睁眼，请查看一张墓地牌并将其与自己以外的一名玩家交换。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("野孩子请睁眼，请交换除自己以外任意两位玩家的底牌但不能查看。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("村民请睁眼，请将自己的身份与一张墓地牌交换但不能查看。")
time.sleep(0.1)
for i in range(8):
    speaker.Speak(str(8-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
time.sleep(0.1)
speaker.Speak("预言家请睁眼，可以查看任意一名玩家的底牌，如果被查看的玩家为好人，则正面朝上")
time.sleep(0.1)
for i in range(5):
    speaker.Speak(str(5-i))
    time.sleep(0.2)
speaker.Speak("请闭眼。")
speaker.Speak("天亮了")
